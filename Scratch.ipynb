# %%
# Initialize weights

# %%
import seaborn as sns
from scipy.stats import norm
#%pylab inline

# %%
sns.distplot(norm.rvs(loc=0,scale=1/500,size=500))
# Out:
# /Users/jonathanhilgart/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(norm.rvs(loc=0,scale=1,size=1000000))
# Out:
# /Users/jonathanhilgart/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
std(norm.rvs(loc=0,scale=1/1000,size=10000) )
# Out:
# 0.0010000916792418102

# %%
from math import sqrt

# %%
sqrt(3/2)
# Out:
# 1.224744871391589

# %%
sqrt(sum([var(norm.rvs(loc=0,scale=1/sqrt(1000),size=50000)) for _ in range(500)]))
# Out:
# 0.7072207833920681

# %%
sqrt(sum([var(norm.rvs(loc=0,scale=1/sqrt(1000),size=50000)) for _ in range(1000)]))
# Out:
# 0.9997840837855182

# %%
[var(norm.rvs(loc=0,scale=1/sqrt(1000),size=500)) for _ in range(500)]
# Out:
# [0.000993433656410769,
#  0.0010107817750176439,
#  0.00090324035240879283,
#  0.0010136976494362301,
#  0.00083224517835917846,
#  0.00095343686526137849,
#  0.00092500651001192313,
#  0.0009235854820395336,
#  0.00088446155654312399,
#  0.0010586352393523295,
#  0.0010260963756903042,
#  0.0010231995435236935,
#  0.00095638179322284935,
#  0.00095245569704064845,
#  0.00096626684782156092,
#  0.0010985692060772338,
#  0.0010395949083959008,
#  0.0010568690876925919,
#  0.0010033571960416795,
#  0.0010014519167101375,
#  0.00093005194129790008,
#  0.00090189432676981464,
#  0.0011195199854934768,
#  0.0010628862246724825,
#  0.0010138708294951417,
#  0.00091871198929849795,
#  0.00095467766554574701,
#  0.0011510786019224937,
#  0.0010837942964318729,
#  0.00094007275686658343,
#  0.0010662401111471973,
#  0.0009617824338899344,
#  0.0010467605805407772,
#  0.00094522794577969857,
#  0.00096964238307950556,
#  0.0008843873757678689,
#  0.00099408514649661824,
# ...
